# %% [markdown]
# Este código compara la evolución de las variables en distintos puntos
# de la somulación.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import numpy.polynomial.polynomial as poly
import matplotlib
import matplotlib.patches as mpatches

# %%
pathrw = '/home/hcapettini/Escritorio/HDD1TB/Tesis/Analísis/Mayo/'
#pathrw = '/media/adminpc/Hilario-2/Tesis/Analísis/Mayo/'

#simulacion ='desequilibrio_3'
simulacion ='pulso_3'
tmin = 0
tmax = 500

path=pathrw +simulacion+'/'+simulacion+'_'

# %%
pos1= '0.2_20.0_'
path1 = path+ pos1

# %%
pos2= '1.5_20.0_'
path2 = path+ pos2

# %%
pos3= '2.8_20.0_'
path3 = path+ pos3

# %%
pos4= '0.2_29.7_'
path4 = path+ pos4

# %%
pos5= '1.5_29.7_'
path5 = path+ pos5

# %%
pos6= '2.8_29.7_'
path6 = path+ pos6

# %%
with open( path1 + 'velx.txt') as velx1:
    velxlines1 = velx1.readlines()[2:]
    time1  = [float(line.split()[0]) for line in velxlines1]
    velxx1 = [float(line.split()[1]) for line in velxlines1]
with open( path1 + 'vely.txt') as vely1:
    velylines1 = vely1.readlines()[2:]
    velyy1 = [float(line.split()[1]) for line in velylines1]
    
with open( path1 + 'magx.txt') as magx1:
    magxlines1 = magx1.readlines()[2:]
    magxx1 = [float(line.split()[1]) for line in magxlines1]
    
with open( path1 + 'magy.txt') as magy1:
    magylines1 = magy1.readlines()[2:]
    magyy1 = [float(line.split()[1]) for line in magylines1]
    
with open( path1 + 'dens.txt') as dens1:
    denslines1 = dens1.readlines()[2:]
    densy1 = [float(line.split()[1]) for line in denslines1]
    
with open( path1 + 'pres.txt') as pres1:
    preslines1 = pres1.readlines()[2:]
    presy1 = [float(line.split()[1]) for line in preslines1]

# %%
with open( path2 + 'velx.txt') as velx2:
    velxlines2 = velx2.readlines()[2:]
    time2  = [float(line.split()[0]) for line in velxlines2]
    velxx2 = [float(line.split()[1]) for line in velxlines2]
with open( path2 + 'vely.txt') as vely2:
    velylines2 = vely2.readlines()[2:]
    velyy2 = [float(line.split()[1]) for line in velylines2]
    
with open( path2 + 'magx.txt') as magx2:
    magxlines2 = magx2.readlines()[2:]
    magxx2 = [float(line.split()[1]) for line in magxlines2]
    
with open( path2 + 'magy.txt') as magy2:
    magylines2 = magy2.readlines()[2:]
    magyy2 = [float(line.split()[1]) for line in magylines2]
    
with open( path2 + 'dens.txt') as dens2:
    denslines2 = dens2.readlines()[2:]
    densy2 = [float(line.split()[1]) for line in denslines2]
    
with open( path2 + 'pres.txt') as pres2:
    preslines2 = pres2.readlines()[2:]
    presy2 = [float(line.split()[1]) for line in preslines2]

# %%
with open( path3 + 'velx.txt') as velx3:
    velxlines3 = velx3.readlines()[2:]
    time3  = [float(line.split()[0]) for line in velxlines3]
    velxx3 = [float(line.split()[1]) for line in velxlines3]
with open( path3 + 'vely.txt') as vely3:
    velylines3 = vely3.readlines()[2:]
    velyy3 = [float(line.split()[1]) for line in velylines3]
    
with open( path3 + 'magx.txt') as magx3:
    magxlines3 = magx3.readlines()[2:]
    magxx3 = [float(line.split()[1]) for line in magxlines3]
    
with open( path3 + 'magy.txt') as magy3:
    magylines3 = magy3.readlines()[2:]
    magyy3 = [float(line.split()[1]) for line in magylines3]
    
with open( path3 + 'dens.txt') as dens3:
    denslines3 = dens3.readlines()[2:]
    densy3 = [float(line.split()[1]) for line in denslines3]
    
with open( path3 + 'pres.txt') as pres3:
    preslines3 = pres3.readlines()[2:]
    presy3 = [float(line.split()[1]) for line in preslines3]

# %%
with open( path4 + 'velx.txt') as velx4:
    velxlines4 = velx4.readlines()[2:]
    time4  = [float(line.split()[0]) for line in velxlines4]
    velxx4 = [float(line.split()[1]) for line in velxlines4]
with open( path4 + 'vely.txt') as vely4:
    velylines4 = vely4.readlines()[2:]
    velyy4 = [float(line.split()[1]) for line in velylines4]
    
with open( path4 + 'magx.txt') as magx4:
    magxlines4 = magx4.readlines()[2:]
    magxx4 = [float(line.split()[1]) for line in magxlines4]
    
with open( path4 + 'magy.txt') as magy4:
    magylines4 = magy4.readlines()[2:]
    magyy4 = [float(line.split()[1]) for line in magylines4]
    
with open( path4 + 'dens.txt') as dens4:
    denslines4 = dens4.readlines()[2:]
    densy4 = [float(line.split()[1]) for line in denslines4]
    
with open( path4 + 'pres.txt') as pres4:
    preslines4 = pres4.readlines()[2:]
    presy4 = [float(line.split()[1]) for line in preslines4]

# %%
with open( path5 + 'velx.txt') as velx5:
    velxlines5 = velx5.readlines()[2:]
    time5  = [float(line.split()[0]) for line in velxlines5]
    velxx5 = [float(line.split()[1]) for line in velxlines5]
with open( path5 + 'vely.txt') as vely5:
    velylines5 = vely5.readlines()[2:]
    velyy5 = [float(line.split()[1]) for line in velylines5]
    
with open( path5 + 'magx.txt') as magx5:
    magxlines5 = magx5.readlines()[2:]
    magxx5 = [float(line.split()[1]) for line in magxlines5]
    
with open( path5 + 'magy.txt') as magy5:
    magylines5 = magy5.readlines()[2:]
    magyy5 = [float(line.split()[1]) for line in magylines5]
    
with open( path5 + 'dens.txt') as dens5:
    denslines5 = dens5.readlines()[2:]
    densy5 = [float(line.split()[1]) for line in denslines5]
    
with open( path5 + 'pres.txt') as pres5:
    preslines5 = pres5.readlines()[2:]
    presy5 = [float(line.split()[1]) for line in preslines5]

# %%
with open( path6 + 'velx.txt') as velx6:
    velxlines6 = velx6.readlines()[2:]
    time6  = [float(line.split()[0]) for line in velxlines6]
    velxx6 = [float(line.split()[1]) for line in velxlines6]
with open( path6 + 'vely.txt') as vely6:
    velylines6 = vely6.readlines()[2:]
    velyy6 = [float(line.split()[1]) for line in velylines6]
    
with open( path6 + 'magx.txt') as magx6:
    magxlines6 = magx6.readlines()[2:]
    magxx6 = [float(line.split()[1]) for line in magxlines6]
    
with open( path6 + 'magy.txt') as magy6:
    magylines6 = magy6.readlines()[2:]
    magyy6 = [float(line.split()[1]) for line in magylines6]
    
with open( path6 + 'dens.txt') as dens6:
    denslines6 = dens6.readlines()[2:]
    densy6 = [float(line.split()[1]) for line in denslines6]
    
with open( path6 + 'pres.txt') as pres6:
    preslines6 = pres6.readlines()[2:]
    presy6 = [float(line.split()[1]) for line in preslines6]

# %%
velx1 = np.array(velxx1)
vely1 = np.array(velyy1)
magx1 = np.array(magxx1)
magy1 = np.array(magyy1)
dens1 = np.array(densy1)
pres1 = np.array(presy1)
time1 = np.array(time1)

# %%
velx2 = np.array(velxx2)
vely2 = np.array(velyy2)
magx2 = np.array(magxx2)
magy2 = np.array(magyy2)
dens2 = np.array(densy2)
pres2 = np.array(presy2)
time2 = np.array(time2)

# %%
velx3 = np.array(velxx3)
vely3 = np.array(velyy3)
magx3 = np.array(magxx3)
magy3 = np.array(magyy3)
dens3 = np.array(densy3)
pres3 = np.array(presy3)
time3 = np.array(time3)

# %%
velx4 = np.array(velxx4)
vely4 = np.array(velyy4)
magx4 = np.array(magxx4)
magy4 = np.array(magyy4)
dens4 = np.array(densy4)
pres4 = np.array(presy4)
time4 = np.array(time4)

# %%
velx5 = np.array(velxx5)
vely5 = np.array(velyy5)
magx5 = np.array(magxx5)
magy5 = np.array(magyy5)
dens5 = np.array(densy5)
pres5 = np.array(presy5)
time5 = np.array(time5)

# %%
velx6 = np.array(velxx6)
vely6 = np.array(velyy6)
magx6 = np.array(magxx6)
magy6 = np.array(magyy6)
dens6 = np.array(densy6)
pres6 = np.array(presy6)
time6 = np.array(time6)

# %%
plt.plot(time1,velx1,label=r'$r=0.2$ [Mm]', linewidth=1)
#plt.plot(time2,velx2,label=r'$r=1.5$ [Mm]', linewidth=1)
#plt.plot(time3,velx3,label=r'$r=2.8$ [Mm]', linewidth=1, color ='red')

plt.legend()
plt.xlim(tmin, tmax)
#plt.ylim(7.e-14,13.e-14)
plt.tick_params( labelsize=17)
plt.ticklabel_format(axis="y", style="sci", scilimits=(5,5))
plt.ylabel(r'${V_r}$ [cm/s]',fontsize=17)  
plt.xlabel(r'$Time$ [s]',fontsize=17)

plt.savefig(pathrw+ simulacion +'/'+simulacion +'_'+'comparación_apex_Vr.pdf', bbox_inches='tight')

# %%
plt.plot(time1,vely1,label=r'$r=0.2$ [Mm]', linewidth=1)
plt.plot(time2,vely2,label=r'$r=1.5$ [Mm]', linewidth=1)
plt.plot(time3,vely3,label=r'$r=2.8$ [Mm]', linewidth=1, color ='red')

plt.legend()
plt.xlim(tmin, tmax)
#plt.ylim(7.e-14,13.e-14)
plt.tick_params( labelsize=17)
plt.ticklabel_format(axis="y", style="sci", scilimits=(5,5))
plt.ylabel(r'${V_z}$ [cm/s]',fontsize=17)  
plt.xlabel(r'$Time$ [s]',fontsize=17)

plt.savefig(pathrw+ simulacion +'/'+simulacion +'_'+'comparación_apex_Vz.pdf', bbox_inches='tight')

# %%
plt.plot(time1,magx1,label=r'$r=0.2$ [Mm]', linewidth=1)
plt.plot(time2,magx2,label=r'$r=1.5$ [Mm]', linewidth=1)
plt.plot(time3,magx3,label=r'$r=2.8$ [Mm]', linewidth=1, color ='red')

plt.legend()
plt.xlim(tmin, tmax)
#plt.ylim(7.e-14,13.e-14)
plt.tick_params( labelsize=17)
plt.ylabel(r'${B_r}$ [G]',fontsize=17)  
plt.xlabel(r'$Time$ [s]',fontsize=17)

plt.savefig(pathrw+ simulacion +'/'+simulacion +'_'+'comparación_apex_Br.pdf', bbox_inches='tight')

# %%
plt.plot(time1,magy1,label=r'$r=0.2$ [Mm]', linewidth=1)
plt.plot(time2,magy2,label=r'$r=1.5$ [Mm]', linewidth=1)
plt.plot(time3,magy3,label=r'$r=2.8$ [Mm]', linewidth=1, color ='red')

plt.legend()
plt.xlim(tmin, tmax)
#plt.ylim(7.e-14,13.e-14)
plt.tick_params( labelsize=17)
plt.ylabel(r'${B_z}$ [G]',fontsize=17)  
plt.xlabel(r'$Time$ [s]',fontsize=17)

plt.savefig(pathrw+ simulacion +'/'+simulacion +'_'+'comparación_apex_Bz.pdf', bbox_inches='tight')

# %%
plt.plot(time1,dens1,label=r'$r=0.2$ [Mm]', linewidth=1)
plt.plot(time2,dens2,label=r'$r=1.5$ [Mm]', linewidth=1)
plt.plot(time3,dens3,label=r'$r=2.8$ [Mm]', linewidth=1, color ='red')

plt.legend()
plt.xlim(tmin, tmax)
#plt.ylim(7.e-14,13.e-14)
plt.tick_params( labelsize=17)
plt.ticklabel_format(axis="y", style="sci", scilimits=(-14,-14))
plt.ylabel(r'${\rho}$ [gr/cm$^3$]',fontsize=17)  
plt.xlabel(r'$Time$ [s]',fontsize=17)

plt.savefig(pathrw+ simulacion +'/'+simulacion +'_'+'comparación_apex_dens.pdf', bbox_inches='tight')

# %%
plt.plot(time1,pres1,label=r'$r=0.2$ [Mm]', linewidth=1)
plt.plot(time2,pres2,label=r'$r=1.5$ [Mm]', linewidth=1)
plt.plot(time3,pres3,label=r'$r=2.8$ [Mm]', linewidth=1, color ='red')

plt.legend()
plt.xlim(tmin, tmax)
#plt.ylim(7.e-14,13.e-14)
plt.tick_params( labelsize=17)
plt.ylabel(r'${P}$ [dyn/cm$^2$]',fontsize=17)  
plt.xlabel(r'$Time$ [s]',fontsize=17)

plt.savefig(pathrw+ simulacion +'/'+simulacion +'_'+'comparación_apex_pres.pdf', bbox_inches='tight')

# %%
plt.plot(time4,velx4,label=r'$r=0.2$ [Mm]', linewidth=1)
plt.plot(time5,velx5,label=r'$r=1.5$ [Mm]', linewidth=1)
plt.plot(time6,velx6,label=r'$r=2.8$ [Mm]', linewidth=1, color ='red')

plt.legend()
plt.xlim(tmin, tmax)
#plt.ylim(7.e-14,13.e-14)
plt.tick_params( labelsize=17)
plt.ticklabel_format(axis="y", style="sci", scilimits=(5,5))
plt.ylabel(r'${V_r}$ [cm/s]',fontsize=17)  
plt.xlabel(r'$Time$ [s]',fontsize=17)

plt.savefig(pathrw+ simulacion +'/'+simulacion +'_'+'comparación_base_Vr.pdf', bbox_inches='tight')

# %%
plt.plot(time4,vely4,label=r'$r=0.2$ [Mm]', linewidth=1)
plt.plot(time5,vely5,label=r'$r=1.5$ [Mm]', linewidth=1)
plt.plot(time6,vely6,label=r'$r=2.8$ [Mm]', linewidth=1, color ='red')

plt.legend()
plt.xlim(tmin, tmax)
#plt.ylim(7.e-14,13.e-14)
plt.tick_params( labelsize=17)
plt.ticklabel_format(axis="y", style="sci", scilimits=(5,5))
plt.ylabel(r'${V_z}$ [cm/s]',fontsize=17)  
plt.xlabel(r'$Time$ [s]',fontsize=17)

plt.savefig(pathrw+ simulacion +'/'+simulacion +'_'+'comparación_base_Vz.pdf', bbox_inches='tight')

# %%
plt.plot(time4,magx4,label=r'$r=0.2$ [Mm]', linewidth=1)
plt.plot(time5,magx5,label=r'$r=1.5$ [Mm]', linewidth=1)
plt.plot(time6,magx6,label=r'$r=2.8$ [Mm]', linewidth=1, color ='red')

plt.legend()
plt.xlim(tmin, tmax)
#plt.ylim(7.e-14,13.e-14)
plt.tick_params( labelsize=17)
plt.ylabel(r'${B_r}$ [G]',fontsize=17)  
plt.xlabel(r'$Time$ [s]',fontsize=17)

plt.savefig(pathrw+ simulacion +'/'+simulacion +'_'+'comparación_base_Br.pdf', bbox_inches='tight')

# %%
plt.plot(time4,magy4,label=r'$r=0.2$ [Mm]', linewidth=1)
plt.plot(time5,magy5,label=r'$r=1.5$ [Mm]', linewidth=1)
plt.plot(time6,magy6,label=r'$r=2.8$ [Mm]', linewidth=1, color ='red')

plt.legend()
plt.xlim(tmin, tmax)
#plt.ylim(7.e-14,13.e-14)
plt.tick_params( labelsize=17)
plt.ylabel(r'${B_z}$ [G]',fontsize=17)  
plt.xlabel(r'$Time$ [s]',fontsize=17)

plt.savefig(pathrw+ simulacion +'/'+simulacion +'_'+'comparación_base_Bz.pdf', bbox_inches='tight')

# %%
plt.plot(time4,dens4,label=r'$r=0.2$ [Mm]', linewidth=1)
plt.plot(time5,dens5,label=r'$r=1.5$ [Mm]', linewidth=1)
#plt.plot(time6,dens6,label=r'$r=2.8$ [Mm]', linewidth=1, color ='red')

plt.legend()
plt.xlim(tmin, tmax)
#plt.ylim(7.e-14,13.e-14)
plt.tick_params( labelsize=17)
plt.ticklabel_format(axis="y", style="sci", scilimits=(-14,-14))
plt.ylabel(r'${\rho}$ [gr/cm$^3$]',fontsize=17)  
plt.xlabel(r'$Time$ [s]',fontsize=17)

plt.savefig(pathrw+ simulacion +'/'+simulacion +'_'+'comparación_base_dens.pdf', bbox_inches='tight')

# %%
plt.plot(time4,pres4,label=r'$r=0.2$ [Mm]', linewidth=1)
plt.plot(time5,pres5,label=r'$r=1.5$ [Mm]', linewidth=1)
plt.plot(time6,pres6,label=r'$r=2.8$ [Mm]', linewidth=1, color ='red')

plt.legend()
plt.xlim(tmin, tmax)
#plt.ylim(7.e-14,13.e-14)
plt.tick_params( labelsize=17)
plt.ylabel(r'${P}$ [dyn/cm$^2$]',fontsize=17)  
plt.xlabel(r'$Time$ [s]',fontsize=17)

plt.savefig(pathrw+ simulacion +'/'+simulacion +'_'+'comparación_base_pres.pdf', bbox_inches='tight')
